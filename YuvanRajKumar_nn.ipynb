# %% [markdown]
# **Problem statement**: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPool2D
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau
from keras.utils.np_utils import to_categorical # convert to one-hot-encoding

# %% [markdown]
# # **Data Summary:**
#
# The dataset consists of images of malignant and benign oncological diseases, which were formed from the International Skin Imaging Collaboration (ISIC).
# 1. Actinic keratosis
# 2. Basal cell carcinoma
# 3. Dermatofibroma
# 4. Melanoma
# 5. Nevus
# 6. Pigmented benign keratosis
# 7. Seborrheic keratosis
# 8. Squamous cell carcinoma
# 9. Vascular lesion

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("C:/yuvan/dataset/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path("C:/yuvan/dataset/Skin cancer ISIC The International Skin Imaging Collaboration/Test")

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2251
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
## Write your test dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_test,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 118 files belonging to 9 classes.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
preprocessing_layers = [
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(180, 180, 3))
]

# %%
### Your code goes here

input_shape = (180,180,3)
lr = 1e-5
init = 'normal'
activ = 'relu'

model = Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(180, 180, 3)))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

## Number of classes is 9
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_6 (Rescaling)     (None, 180, 180, 3)       0
#
#  module_wrapper_58 (ModuleWr  (None, 178, 178, 32)     896
#  apper)
#
#  module_wrapper_59 (ModuleWr  (None, 176, 176, 32)     9248
#  apper)
#
#  module_wrapper_60 (ModuleWr  (None, 88, 88, 32)       0
#  apper)
#
#  module_wrapper_61 (ModuleWr  (None, 86, 86, 64)       18496
#  apper)
#
#  batch_normalization_2 (Batc  (None, 86, 86, 64)       256
#  hNormalization)
#
#  module_wrapper_62 (ModuleWr  (None, 43, 43, 64)       0
#  apper)
#
#  module_wrapper_63 (ModuleWr  (None, 41, 41, 128)      73856
#  apper)
#
#  batch_normalization_3 (Batc  (None, 41, 41, 128)      512
#  hNormalization)
#
#  module_wrapper_64 (ModuleWr  (None, 20, 20, 128)      0
#  apper)
#
#  module_wrapper_65 (ModuleWr  (None, 51200)            0
#  apper)
#
#  module_wrapper_66 (ModuleWr  (None, 512)              26214912
#  apper)
#
#  module_wrapper_67 (ModuleWr  (None, 512)              0
#  apper)
#
#  module_wrapper_68 (ModuleWr  (None, 512)              0
#  apper)
#
#  module_wrapper_69 (ModuleWr  (None, 1)                513
#  apper)
#
#  module_wrapper_70 (ModuleWr  (None, 1)                0
#  apper)
#
# =================================================================
# Total params: 26,318,689
# Trainable params: 26,318,305
# Non-trainable params: 384
# _________________________________________________________________

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function

optimizer = 'adam'
loss_fn = "binary_crossentropy"
model.compile(optimizer=optimizer,
              loss=loss_fn,
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_5 (Rescaling)     (None, 180, 180, 3)       0
#
#  module_wrapper (ModuleWrapp  (None, 178, 178, 32)     896
#  er)
#
#  module_wrapper_1 (ModuleWra  (None, 176, 176, 32)     9248
#  pper)
#
#  module_wrapper_2 (ModuleWra  (None, 88, 88, 32)       0
#  pper)
#
#  module_wrapper_3 (ModuleWra  (None, 86, 86, 64)       18496
#  pper)
#
#  batch_normalization (BatchN  (None, 86, 86, 64)       256
#  ormalization)
#
#  module_wrapper_4 (ModuleWra  (None, 43, 43, 64)       0
#  pper)
#
#  module_wrapper_5 (ModuleWra  (None, 41, 41, 128)      73856
#  pper)
#
#  batch_normalization_1 (Batc  (None, 41, 41, 128)      512
#  hNormalization)
#
#  module_wrapper_6 (ModuleWra  (None, 20, 20, 128)      0
#  pper)
#
#  module_wrapper_7 (ModuleWra  (None, 51200)            0
#  pper)
#
#  module_wrapper_8 (ModuleWra  (None, 512)              26214912
#  pper)
#
#  module_wrapper_9 (ModuleWra  (None, 512)              0
#  pper)
#
#  module_wrapper_10 (ModuleWr  (None, 512)              0
#  apper)
#
#  module_wrapper_11 (ModuleWr  (None, 1)                513
#  apper)
#
#  module_wrapper_12 (ModuleWr  (None, 1)                0
#  apper)
#
# =================================================================
# Total params: 26,318,689
# Trainable params: 26,318,305
# Non-trainable params: 384
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
batch_size = 32

history = model.fit(
  train_ds,
  batch_size=batch_size,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 119s 2s/step - loss: -71440.5234 - accuracy: 0.1713 - val_loss: -77274.3203 - val_accuracy: 0.1499
# Epoch 2/20
# 56/56 [==============================] - 115s 2s/step - loss: -773418.8125 - accuracy: 0.1724 - val_loss: -826314.6250 - val_accuracy: 0.1499
# Epoch 3/20
# 56/56 [==============================] - 123s 2s/step - loss: -2844181.7500 - accuracy: 0.1724 - val_loss: -3156518.7500 - val_accuracy: 0.1499
# Epoch 4/20
# 56/56 [==============================] - 122s 2s/step - loss: -6954625.5000 - accuracy: 0.1724 - val_loss: -8628528.0000 - val_accuracy: 0.1499
# Epoch 5/20
# 56/56 [==============================] - 125s 2s/step - loss: -13989513.0000 - accuracy: 0.1724 - val_loss: -16737958.0000 - val_accuracy: 0.1499
# Epoch 6/20
# 56/56 [==============================] - 121s 2s/step - loss: -24521820.0000 - accuracy: 0.1724 - val_loss: -26802980.0000 - val_accuracy: 0.1499
# Epoch 7/20
# 56/56 [==============================] - 119s 2s/step - loss: -39352748.0000 - accuracy: 0.1724 - val_loss: -37891960.0000 - val_accuracy: 0.1499
# Epoch 8/20
# 56/56 [==============================] - 143s 3s/step - loss: -57774652.0000 - accuracy: 0.1724 - val_loss: -47070152.0000 - val_accuracy: 0.1499
# Epoch 9/20
# 56/56 [==============================] - 125s 2s/step - loss: -81964120.0000 - accuracy: 0.1724 - val_loss: -88979888.0000 - val_accuracy: 0.1499
# Epoch 10/20
# 56/56 [==============================] - 133s 2s/step - loss: -112945400.0000 - accuracy: 0.1724 - val_loss: -127525768.0000 - val_accuracy: 0.1499
# Epoch 11/20
# 56/56 [==============================] - 123s 2s/step - loss: -149593552.0000 - accuracy: 0.1724 - val_loss: -129551992.0000 - val_accuracy: 0.1499
# Epoch 12/20
# 56/56 [==============================] - 137s 2s/step - loss: -193413712.0000 - accuracy: 0.1724 - val_loss: -243841488.0000 - val_accuracy: 0.1499
# Epoch 13/20
# 56/56 [==============================] - 123s 2s/step - loss: -239398704.0000 - accuracy: 0.1724 - val_loss: -232837456.0000 - val_accuracy: 0.1499
# Epoch 14/20
# 56/56 [==============================] - 119s 2s/step - loss: -301813312.0000 - accuracy: 0.1724 - val_loss: -231397904.0000 - val_accuracy: 0.1499
# Epoch 15/20
# 56/56 [==============================] - 114s 2s/step - loss: -367275424.0000 - accuracy: 0.1724 - val_loss: -376987488.0000 - val_accuracy: 0.1499
# Epoch 16/20
# 56/56 [==============================] - 112s 2s/step - loss: -442119008.0000 - accuracy: 0.1724 - val_loss: -423207136.0000 - val_accuracy: 0.1499
# Epoch 17/20
# 56/56 [==============================] - 112s 2s/step - loss: -528185536.0000 - accuracy: 0.1724 - val_loss: -528672288.0000 - val_accuracy: 0.1499
# Epoch 18/20
# 56/56 [==============================] - 112s 2s/step - loss: -620555328.0000 - accuracy: 0.1724 - val_loss: -521263264.0000 - val_accuracy: 0.1499
# Epoch 19/20
# 56/56 [==============================] - 118s 2s/step - loss: -724194752.0000 - accuracy: 0.1724 - val_loss: -980493632.0000 - val_accuracy: 0.1499
# Epoch 20/20
# 56/56 [==============================] - 112s 2s/step - loss: -833420416.0000 - accuracy: 0.1724 - val_loss: -759229952.0000 - val_accuracy: 0.1499

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']


epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Model Overfit or Underfit?

# %%
loss, accuracy = model.evaluate(train_ds, verbose=1,)
loss_v, accuracy_v = model.evaluate(val_ds, verbose=1)

print("Accuracy: ", accuracy)
print("Validation Accuracy: ",accuracy_v)
print("Loss: ",loss)
print("Validation Loss", loss_v)


# Thus we can clearly that model Overfit and we need to chose right data augumentation strategy
# Out:
# 56/56 [==============================] - 17s 307ms/step - loss: -743258240.0000 - accuracy: 0.1724
# 14/14 [==============================] - 5s 376ms/step - loss: -759229952.0000 - accuracy: 0.1499
# Accuracy:  0.1724330335855484
# Validation Accuracy:  0.14988814294338226
# Loss:  -743258240.0
# Validation Loss -759229952.0

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images

image_class = ['nevus','melanoma','basal_cell_caricoma','actinic_keratosis','vasc_lesion','dermatofibroma', 'pigmented_keratosis', 'seborrheic_keratosis', 'squamous_carci']

train_batches = datagen.flow_from_directory(data_dir_train, 
    target_size = (180,180),
    classes = image_class,
    batch_size = 64
 )

valid_batches = datagen.flow_from_directory(data_dir_test, 
    target_size = (180,180),
    classes = image_class,
    batch_size = 64
)
# Out:
# Found 890 images belonging to 9 classes.
# Found 48 images belonging to 9 classes.

# %%
# visualize how your augmentation strategy works for one instance of training image.
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

input_shape = (180,180,3)
model = Sequential()

# Increse the model size by adding another 32 layer
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(180, 180, 3)))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
# Max Pool size of 2*2
model.add(MaxPool2D(pool_size=(2, 2)))

# Adding Dropout Layer
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(9, activation='softmax'))
model.build(input_shape)
model.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_8 (Rescaling)     (None, 180, 180, 3)       0
#
#  module_wrapper_296 (ModuleW  (None, 178, 178, 32)     896
#  rapper)
#
#  module_wrapper_297 (ModuleW  (None, 176, 176, 32)     9248
#  rapper)
#
#  module_wrapper_298 (ModuleW  (None, 88, 88, 32)       0
#  rapper)
#
#  module_wrapper_299 (ModuleW  (None, 88, 88, 32)       0
#  rapper)
#
#  module_wrapper_300 (ModuleW  (None, 88, 88, 64)       18496
#  rapper)
#
#  module_wrapper_301 (ModuleW  (None, 88, 88, 64)       36928
#  rapper)
#
#  module_wrapper_302 (ModuleW  (None, 44, 44, 64)       0
#  rapper)
#
#  module_wrapper_303 (ModuleW  (None, 44, 44, 64)       0
#  rapper)
#
#  module_wrapper_304 (ModuleW  (None, 42, 42, 128)      73856
#  rapper)
#
#  module_wrapper_305 (ModuleW  (None, 21, 21, 128)      0
#  rapper)
#
#  module_wrapper_306 (ModuleW  (None, 21, 21, 128)      0
#  rapper)
#
#  module_wrapper_307 (ModuleW  (None, 56448)            0
#  rapper)
#
#  module_wrapper_308 (ModuleW  (None, 512)              28901888
#  rapper)
#
#  module_wrapper_309 (ModuleW  (None, 512)              0
#  rapper)
#
#  module_wrapper_310 (ModuleW  (None, 9)                4617
#  rapper)
#
# =================================================================
# Total params: 29,045,929
# Trainable params: 29,045,929
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compiling the model

# %%
model.compile?

# %%
optimizer = 'adam'
loss_fn = "categorical_crossentropy"
model.compile(optimizer=optimizer,
              loss=loss_fn,
              metrics=['accuracy'])

# %% [markdown]
# In order to make the optimizer converge faster and closest to the global minimum of the loss function, i used an annealing method of the learning rate (LR).
#
# The LR is the step by which the optimizer walks through the 'loss landscape'. The higher LR, the bigger are the steps and the quicker is the convergence. However the sampling is very poor with an high LR and the optimizer could probably fall into a local minima.

# %%
# Set a learning rate annealer
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
    patience=3, 
    verbose=1, 
    factor=0.5, 
    min_lr=0.00001)

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
epochs = 20
batch_size = 10
history = model.fit(train_batches,
  epochs = epochs, verbose = 1, validation_data=valid_batches , callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/20
# 14/14 [==============================] - 79s 6s/step - loss: 2.1012 - accuracy: 0.4438 - val_loss: 1.7525 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 2/20
# 14/14 [==============================] - 74s 5s/step - loss: 0.9899 - accuracy: 0.4730 - val_loss: 1.5098 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 3/20
# 14/14 [==============================] - 75s 5s/step - loss: 0.9510 - accuracy: 0.4865 - val_loss: 1.3021 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 4/20
# 14/14 [==============================] - ETA: 0s - loss: 0.9295 - accuracy: 0.4888
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 14/14 [==============================] - 74s 5s/step - loss: 0.9295 - accuracy: 0.4888 - val_loss: 1.2482 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 5/20
# 14/14 [==============================] - 75s 5s/step - loss: 0.8618 - accuracy: 0.5461 - val_loss: 1.1767 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 6/20
# 14/14 [==============================] - 89s 6s/step - loss: 0.8379 - accuracy: 0.5820 - val_loss: 1.1766 - val_accuracy: 0.3542 - lr: 5.0000e-04
# Epoch 7/20
# 14/14 [==============================] - 79s 6s/step - loss: 0.8017 - accuracy: 0.6056 - val_loss: 1.1167 - val_accuracy: 0.4167 - lr: 5.0000e-04
# Epoch 8/20
# 14/14 [==============================] - 75s 5s/step - loss: 0.7517 - accuracy: 0.6326 - val_loss: 1.1409 - val_accuracy: 0.3750 - lr: 5.0000e-04
# Epoch 9/20
# 14/14 [==============================] - 106s 8s/step - loss: 0.7223 - accuracy: 0.6562 - val_loss: 1.2005 - val_accuracy: 0.4583 - lr: 5.0000e-04
# Epoch 10/20
# 14/14 [==============================] - 99s 7s/step - loss: 0.7186 - accuracy: 0.6742 - val_loss: 1.2506 - val_accuracy: 0.4792 - lr: 5.0000e-04
# Epoch 11/20
# 14/14 [==============================] - 80s 6s/step - loss: 0.6681 - accuracy: 0.6697 - val_loss: 1.3762 - val_accuracy: 0.5417 - lr: 5.0000e-04
# Epoch 12/20
# 14/14 [==============================] - 77s 5s/step - loss: 0.6426 - accuracy: 0.6899 - val_loss: 1.5130 - val_accuracy: 0.5208 - lr: 5.0000e-04
# Epoch 13/20
# 14/14 [==============================] - 75s 5s/step - loss: 0.6599 - accuracy: 0.6899 - val_loss: 1.3918 - val_accuracy: 0.5833 - lr: 5.0000e-04
# Epoch 14/20
# 14/14 [==============================] - 78s 5s/step - loss: 0.6522 - accuracy: 0.6809 - val_loss: 1.5806 - val_accuracy: 0.5417 - lr: 5.0000e-04
# Epoch 15/20
# 14/14 [==============================] - 74s 5s/step - loss: 0.6011 - accuracy: 0.7337 - val_loss: 1.4699 - val_accuracy: 0.5417 - lr: 5.0000e-04
# Epoch 16/20
# 14/14 [==============================] - ETA: 0s - loss: 0.6467 - accuracy: 0.6820
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 14/14 [==============================] - 76s 5s/step - loss: 0.6467 - accuracy: 0.6820 - val_loss: 1.6758 - val_accuracy: 0.5208 - lr: 5.0000e-04
# Epoch 17/20
# 14/14 [==============================] - 77s 5s/step - loss: 0.5941 - accuracy: 0.7258 - val_loss: 1.8083 - val_accuracy: 0.5417 - lr: 2.5000e-04
# Epoch 18/20
# 14/14 [==============================] - 74s 5s/step - loss: 0.5817 - accuracy: 0.7348 - val_loss: 1.6592 - val_accuracy: 0.5625 - lr: 2.5000e-04
# Epoch 19/20
# 14/14 [==============================] - ETA: 0s - loss: 0.5915 - accuracy: 0.7270
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 14/14 [==============================] - 76s 5s/step - loss: 0.5915 - accuracy: 0.7270 - val_loss: 1.7820 - val_accuracy: 0.5625 - lr: 2.5000e-04
# Epoch 20/20
# 14/14 [==============================] - 77s 5s/step - loss: 0.5665 - accuracy: 0.7416 - val_loss: 1.7344 - val_accuracy: 0.5625 - lr: 1.2500e-04

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
print(history.history.keys, ":")
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# <built-in method keys of dict object at 0x000002DA9C954E00> :

# %% [markdown]
# #### Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# #### Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
import matplotlib.pyplot as plt
data = dict()

for i in class_names:
  data[i] = []

plt.figure(figsize=(10, 10))
for images, labels in train_ds:
  for i in range(9):
    data[class_names[labels[i]]].append(images[i].numpy().astype("uint8"))

for i in data:
  data[i] = len(data[i]) 

f = plt.figure()
f.set_figwidth(20)
f.set_figheight(20)

plt.bar(range(len(data)), list(data.values()), align='center')
plt.xticks(range(len(data)), list(data.keys()))
plt.show()

# %% [markdown]
# #### Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %% [markdown]
# #### - Which class has the least number of samples? - **Actinic Keratosos** and **Seborrheic keratosis**
# #### - Which classes dominate the data in terms proportionate number of samples?
# **Pigmented benign keratosis** dominates the data of count more than 100 in training

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: future>=0.16.0 in c:\users\ac96717\anaconda3\lib\site-packages (from Augmentor) (0.18.2)
# Requirement already satisfied: numpy>=1.11.0 in c:\users\ac96717\anaconda3\lib\site-packages (from Augmentor) (1.20.3)
# Requirement already satisfied: tqdm>=4.9.0 in c:\users\ac96717\anaconda3\lib\site-packages (from Augmentor) (4.62.3)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\ac96717\anaconda3\lib\site-packages (from Augmentor) (8.4.0)
# Requirement already satisfied: colorama in c:\users\ac96717\anaconda3\lib\site-packages (from tqdm>=4.9.0->Augmentor) (0.4.4)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.10

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
#path_to_training_dataset=pathlib.Path("C:/yuvan/dataset/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
# data_dir_train = pathlib.Path(root_path + '/Train')
data_dir_train = pathlib.Path("C:/yuvan/dataset/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 2239 image(s) found.
# Output directory set to C:\yuvan\dataset\Skin cancer ISIC The International Skin Imaging Collaboration\Train\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x2DA9C95EEB0>: 100%|█| 500/500 [00:09<00:
# Initialised with 2239 image(s) found.
# Output directory set to C:\yuvan\dataset\Skin cancer ISIC The International Skin Imaging Collaboration\Train\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x2DA9DB24280>: 100%|█| 500/500 [00:11<00:00, 42.17 Samples/
# Initialised with 2239 image(s) found.
# Output directory set to C:\yuvan\dataset\Skin cancer ISIC The International Skin Imaging Collaboration\Train\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x2DA9C533820>: 100%|█| 500/500 [00:13<00:00, 36.60 Samples/
# Initialised with 2239 image(s) found.
# Output directory set to C:\yuvan\dataset\Skin cancer ISIC The International Skin Imaging Collaboration\Train\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x2DA9C5137C0>: 100%|█| 500/500 [00:10<00:00, 46.83 Samples/
# Initialised with 2239 image(s) found.
# Output directory set to C:\yuvan\dataset\Skin cancer ISIC The International Skin Imaging Collaboration\Train\output.
# Processing <PIL.Image.Image image mode=RGB size=2048x1536 at 0x2DA9C92C3A0>: 100%|█| 500/500 [00:13<00:00, 36.66 Sample
# Initialised with 2239 image(s) found.
# Output directory set to C:\yuvan\dataset\Skin cancer ISIC The International Skin Imaging Collaboration\Train\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x2DA9DA37610>: 100%|█| 500/500 [00:13<00:00, 38.25 Samples/
# Initialised with 2239 image(s) found.
# Output directory set to C:\yuvan\dataset\Skin cancer ISIC The International Skin Imaging Collaboration\Train\output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x2DA9DB21490>: 100%|█| 500/500 [00:12<00:00, 40.96 Samples
# Initialised with 2239 image(s) found.
# Output directory set to C:\yuvan\dataset\Skin cancer ISIC The International Skin Imaging Collaboration\Train\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x2DA9C6BA3A0>: 100%|█| 500/500 [00:15<00:00, 33.07 Samples/
# Initialised with 2239 image(s) found.
# Output directory set to C:\yuvan\dataset\Skin cancer ISIC The International Skin Imaging Collaboration\Train\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x2DA9C474550>: 100%|█| 500/500 [00:15<00:00, 31.73 Samples/

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### Create a training dataset

# %%
data_dir_train=pathlib.Path("C:/yuvan/dataset/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 11239 files belonging to 10 classes.
# Using 8992 files for training.

# %% [markdown]
# #### Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 11239 files belonging to 10 classes.
# Using 2247 files for validation.

# %% [markdown]
# #### Create your model (make sure to include normalization)

# %%
input_shape = (180,180,3)
model = Sequential()

# Increse the model size by adding another 32 layer
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(180, 180, 3)))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))

# Max Pool size of 2*2
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(BatchNormalization())
# Adding Dropout Layer
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_9 (Rescaling)     (None, 180, 180, 3)       0
#
#  module_wrapper_326 (ModuleW  (None, 178, 178, 32)     896
#  rapper)
#
#  module_wrapper_327 (ModuleW  (None, 176, 176, 32)     9248
#  rapper)
#
#  module_wrapper_328 (ModuleW  (None, 88, 88, 32)       0
#  rapper)
#
#  batch_normalization_8 (Batc  (None, 88, 88, 32)       128
#  hNormalization)
#
#  module_wrapper_329 (ModuleW  (None, 88, 88, 32)       0
#  rapper)
#
#  module_wrapper_330 (ModuleW  (None, 88, 88, 64)       18496
#  rapper)
#
#  module_wrapper_331 (ModuleW  (None, 88, 88, 64)       36928
#  rapper)
#
#  module_wrapper_332 (ModuleW  (None, 44, 44, 64)       0
#  rapper)
#
#  batch_normalization_9 (Batc  (None, 44, 44, 64)       256
#  hNormalization)
#
#  module_wrapper_333 (ModuleW  (None, 44, 44, 64)       0
#  rapper)
#
#  module_wrapper_334 (ModuleW  (None, 42, 42, 128)      73856
#  rapper)
#
#  batch_normalization_10 (Bat  (None, 42, 42, 128)      512
#  chNormalization)
#
#  module_wrapper_335 (ModuleW  (None, 21, 21, 128)      0
#  rapper)
#
#  module_wrapper_336 (ModuleW  (None, 21, 21, 128)      0
#  rapper)
#
#  module_wrapper_337 (ModuleW  (None, 56448)            0
#  rapper)
#
#  module_wrapper_338 (ModuleW  (None, 128)              7225472
#  rapper)
#
#  batch_normalization_11 (Bat  (None, 128)              512
#  chNormalization)
#
#  module_wrapper_339 (ModuleW  (None, 128)              0
#  rapper)
#
#  module_wrapper_340 (ModuleW  (None, 1)                129
#  rapper)
#
# =================================================================
# Total params: 7,366,433
# Trainable params: 7,365,729
# Non-trainable params: 704
# _________________________________________________________________

# %% [markdown]
# #### Compile your model (Choose optimizer and loss function appropriately)

# %%
optimizer = 'adam'
loss_fn = "categorical_crossentropy"
model.compile(optimizer=optimizer,
              loss=loss_fn,
              metrics=['accuracy'])

# %% [markdown]
# ####  Train your model

# %%
epochs = 50

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
    patience=3, 
    verbose=1, 
    factor=0.5, 
    min_lr=0.00001)

batch_size = 10
history = model.fit(train_ds,
  epochs = epochs, verbose = 1, validation_data=val_ds , callbacks=[learning_rate_reduction])

# %% [markdown]
# ####  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# The class rebalance helped in reducing overfititng of the data and thus the loass is beng reduced
# But it reduced the Acurracy very low
#
#
# Initially we tried without the ImageDataGenerator which created data to over fit at high ratio
#
# Then we introduced dropout and ImageDataGenerator which reduced the over fit
#
# At last we tried Batch Normalization and Augumentation which really helped in carry forward
